# %%
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
#engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")

#Create engine from LOCALLY HOSTED SQLITE DATABASE
engine = create_engine('sqlite+pysqlite:///test.sqlite')

# Store the engine's connection configuration as a variable to inform Pandas where to send the query
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['Player_Attributes',
#  'Team_Attributes',
#  'champions',
#  'country',
#  'datanew',
#  'league',
#  'match',
#  'player',
#  'team']

# %%
pd.read_sql("SELECT * FROM champions", conn)
# Out:
#    index  awayTeam.id          awayTeam.name                    group  \
# 0      0         7282        Drita KF Gjilan  Preliminary Semi-finals
# 1      1         7281    Lincoln Red Imps FC  Preliminary Semi-finals
# 2      2         7282        Drita KF Gjilan        Preliminary Final
# 3      3         1880    FC Sheriff Tiraspol                     None
# 4      4         1891  Hapoel Be'er Sheva FC                     None
# 5      5         5961            MOL Vidi FC                     None
# 6      6          732              Celtic FC                     None
# 7      7         5123                    HJK                     None
# 8      8         1904      The New Saints FC                     None
# 9      9          749               Malmö FF                     None
#
#    homeTeam.id        homeTeam.name      id           lastUpdated matchday  \
# 0         1879      FC Santa Coloma  238916  2019-01-11T17:30:05Z     None
# 1         1902        SP La Fiorita  238917  2019-01-11T17:30:05Z     None
# 2         7281  Lincoln Red Imps FC  238918  2019-01-11T17:30:05Z     None
# 3         7286   FC Torpedo Kutaisi  238919  2019-01-11T17:30:05Z     None
# 4         5100             FC Flora  238941  2019-01-11T17:30:06Z     None
# 5         1875        F91 Diddeleng  238927  2019-01-11T17:30:05Z     None
# 6         1870         Alashkert FC  238945  2019-01-11T17:30:06Z     None
# 7         1905        Víkingur Gøta  238931  2019-01-11T17:30:05Z     None
# 8         7285      KF Shkëndija 79  238921  2019-01-11T17:30:05Z     None
# 9         7282      Drita KF Gjilan  238929  2019-01-11T17:30:05Z     None
#
#                                             referees          ...           \
# 0  [{'id': 37252, 'name': 'Paul McLaughlin', 'nat...          ...
# 1  [{'id': 23975, 'name': 'Jørgen Burchardt', 'na...          ...
# 2  [{'id': 40217, 'name': 'Manfredas Lukjančukas'...          ...
# 3  [{'id': 43841, 'name': 'Aleksandrs Golubevs', ...          ...
# 4  [{'id': 17631, 'name': 'Erik Lambrechts', 'nat...          ...
# 5  [{'id': 82338, 'name': 'Zaven Hovhannisyan', '...          ...
# 6  [{'id': 9376, 'name': 'Danilo Grujić', 'nation...          ...
# 7  [{'id': 15214, 'name': 'Robert Hennessy', 'nat...          ...
# 8  [{'id': 82333, 'name': 'Timotheos Christofi', ...          ...
# 9  [{'id': 79620, 'name': 'Boris Marhefka', 'nati...          ...
#
#   score.penalties.awayTeam  score.penalties.homeTeam  score.winner  \
# 0                     None                      None     AWAY_TEAM
# 1                     None                      None     AWAY_TEAM
# 2                     None                      None     AWAY_TEAM
# 3                     None                      None     HOME_TEAM
# 4                     None                      None     AWAY_TEAM
# 5                     None                      None          DRAW
# 6                     None                      None     AWAY_TEAM
# 7                     None                      None     AWAY_TEAM
# 8                     None                      None     HOME_TEAM
# 9                     None                      None     AWAY_TEAM
#
#    season.currentMatchday  season.endDate  season.id  season.startDate  \
# 0                       7        6/1/2019        175         6/26/2018
# 1                       7        6/1/2019        175         6/26/2018
# 2                       7        6/1/2019        175         6/26/2018
# 3                       7        6/1/2019        175         6/26/2018
# 4                       7        6/1/2019        175         6/26/2018
# 5                       7        6/1/2019        175         6/26/2018
# 6                       7        6/1/2019        175         6/26/2018
# 7                       7        6/1/2019        175         6/26/2018
# 8                       7        6/1/2019        175         6/26/2018
# 9                       7        6/1/2019        175         6/26/2018
#
#                      stage    status               utcDate
# 0  PRELIMINARY_SEMI_FINALS  FINISHED  2018-06-26T15:00:00Z
# 1  PRELIMINARY_SEMI_FINALS  FINISHED  2018-06-26T19:00:00Z
# 2        PRELIMINARY_FINAL  FINISHED  2018-06-29T18:30:00Z
# 3     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T15:30:00Z
# 4     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T15:30:00Z
# 5     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T16:00:00Z
# 6     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T16:00:00Z
# 7     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T18:00:00Z
# 8     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T18:15:00Z
# 9     1ST_QUALIFYING_ROUND  FINISHED  2018-07-10T18:45:00Z
#
# [10 rows x 27 columns]
